// %% [raw]
// # JBang Jupyter notebook example
//
// You can write normal Java.

// %%
var result = 2 + 2;
result
// Out:
// 4

// %%
// including classes
record Person(double a, double b) {
    public Complex add(Complex c) {
        return new Complex(a+c.a, b+c.b);
    }
}
Complex x = new Complex(10,20);
x.add(new Complex(1,1))
// Out:
// |   // including classes
// |   record Person(double a, double b) {
// |       public Complex add(Complex c) {
// |           return new Complex(a+c.a, b+c.b);
// |       }
// |   }
// Unresolved dependencies:
//    - class Complex

// %% [markdown]
// ## Dependency management
//
// You can add dependencies using jbang's traditional `//DEPS` directive.

// %% [markdown]
// When added you can import and use the dependency.

// %% [raw]
// //DEPS com.github.javafaker:javafaker:1.0.2

// %%
import com.github.javafaker.Faker;
// Out:
// |   import com.github.javafaker.Faker;
// package com.github.javafaker does not exist

// %%
var faker = new Faker();
faker.name().fullName()
// Out:
// |   var faker = new Faker();
// cannot find symbol
//   symbol:   class Faker

// %% [markdown]
// ## Help on magic commands
//
// The magic `%help` provides info

// %%
%help
// Out:
// Welcome to the JBang Jupyter kernel.
//
// This is still a work in progress. Please provide feedback at
// https://github.com/jbangdev/jbang-jupyter
//
// Available magics:
// %jbang
// %help
// %load
// %log
//
// JBang executable found at /home/mos/.sdkman/candidates/jbang/current/bin/jbang
// Java version: 24.0.2
// Java vendor: Amazon.com Inc.
// Java vendor URL: https://aws.amazon.com/corretto/
// Java home: /home/mos/.sdkman/candidates/java/24.0.2-amzn
// Java class path: /home/mos/.jbang/cache/urls/5be19ba5d4916ff8990f678b9290b1c50898eb540469fc2649a5bf5d2e2096ac/jbang-jupyter-0.1.0-SNAPSHOT-fatjar.jar
// Java library path: /usr/java/packages/lib:/usr/lib64:/lib64:/lib:/usr/lib

// %% [markdown]
// ## Display data
//
// You can display data. For example we display a markdown snippet and we direct the output interpretation of the snippet through MIME type.

// %%
display("Markdown *test* **snippet**:\n* bullet 1\n* bullet 2", "text/markdown")
// Out:
// Markdown *test* **snippet**:
// * bullet 1
// * bullet 2
// 0ded9f95-8235-4d8e-8e04-c56804091db5
